# %%
import treasury
from datetime import datetime
import importlib
importlib.reload(treasury)
# Out:
# <module 'treasury' from 'c:\\Users\\17Fry\\Projects\\treasury-curves\\treasury.py'>

# %%
# get curves data for today
curves_data = treasury.curves(allow_missing=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [2], line 2
#       1 # get curves data for today
# ----> 2 curves_data = treasury.curves(date=datetime.today(), allow_missing=True)
#
# File c:\Users\17Fry\Projects\treasury-curves\treasury.py:22, in curves(date, allow_missing)
#      20 """get treasury curves for today or a specific date"""
#      21 date = datetime.today().strftime(DATE_FMT) if date is None else date
# ---> 22 date = datetime.strptime(date, DATE_FMT)
#      23 dt_str = date.strftime(DATE_FMT)
#      24 dt_range = pd.date_range(end=dt_str, periods=50, freq="12M").shift(date.day, freq="D")
#
# TypeError: strptime() argument 1 must be str, not datetime.datetime

# %%
# plot curves data 
treasury.plot(curves_data, end_year=2022, num_years=4)
# Out:
#       1 Yr  2 Yr  5 Yr  10 Yr  20 Yr  30 Yr
# Year
# 2022  4.05  3.95  3.69   3.49   3.77   3.52
# 2021  0.07  0.23  0.83   1.31   1.79   1.85
# 2020  0.13  0.14  0.29   0.70   1.24   1.45
# 2019  1.87  1.77  1.68   1.80   2.06   2.25

# %%
# display available treasury curve data
curves_data
# Out:
#            Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Year
# 1990 1990-09-17   NaN   NaN  7.61  7.66  7.73  8.05  8.23  8.49  8.78   8.90
# 1991 1991-09-18   NaN   NaN  5.34  5.45  5.56  6.18  6.48  7.10  7.43   7.62
# 1992 1992-09-18   NaN   NaN  2.94  2.99  3.13  3.86  4.40  5.41  5.97   6.41
# 1993 1993-09-17   NaN   NaN  3.01  3.17  3.39  3.89  4.19  4.75  5.11   5.38
# 1994 1994-09-19   NaN   NaN  4.72  5.23  5.78  6.39  6.71  7.11  7.32   7.49
# 1995 1995-09-18   NaN   NaN  5.41  5.47  5.56  5.77  5.86  5.97  6.11   6.17
# 1996 1996-09-17   NaN   NaN  5.31  5.46  5.83  6.22  6.39  6.57  6.71   6.81
# 1997 1997-09-19   NaN   NaN  5.06  5.27  5.48  5.81  5.89  6.01  6.08   6.09
# 1998 1998-09-17   NaN   NaN  4.70  4.83  4.76  4.70  4.63  4.60  4.74   4.80
# 1999 1999-09-17   NaN   NaN  4.67  5.07  5.24  5.63  5.74  5.76  6.06   5.87
# 2000 2000-09-20   NaN   NaN  6.16  6.23  6.10  6.11  6.06  5.98  6.06   5.91
# 2001 2001-09-19  2.00   NaN  2.19  2.33  2.49  2.81  3.18  3.90  4.41   4.69
# 2002 2002-09-19  1.64   NaN  1.65  1.64  1.68  1.93  2.24  2.87  3.42   3.79
# 2003 2003-09-19  0.88   NaN  0.95  1.02  1.23  1.70  2.20  3.11  3.66   4.17
# 2004 2004-09-17  1.58   NaN  1.71  1.90  2.11  2.53  2.83  3.35  3.75   4.14
# 2005 2005-09-19  3.23   NaN  3.58  3.84  3.87  3.93  3.95  4.02  4.11   4.25
# 2006 2006-09-19  4.72   NaN  4.94  5.09  4.99  4.79  4.72  4.69  4.69   4.74
# 2007 2007-09-20  3.46   NaN  3.79  4.11  4.10  4.10  4.19  4.35  4.49   4.69
# 2008 2008-09-17  0.07   NaN  0.03  1.03  1.50  1.64  1.91  2.52  2.93   3.41
# 2009 2009-09-17  0.03   NaN  0.10  0.20  0.40  0.98  1.51  2.41  3.04   3.42
# 2010 2010-09-20  0.12   NaN  0.17  0.20  0.26  0.47  0.73  1.43  2.10   2.72
# 2011 2011-09-20  0.00   NaN  0.01  0.03  0.09  0.18  0.30  0.85  1.39   1.95
# 2012 2012-09-19  0.08   NaN  0.11  0.14  0.18  0.27  0.35  0.70  1.18   1.79
# 2013 2013-09-19  0.00   NaN  0.01  0.03  0.10  0.34  0.69  1.49  2.13   2.76
# 2014 2014-09-17  0.01   NaN  0.02  0.05  0.12  0.59  1.08  1.82  2.29   2.62
# 2015 2015-09-18  0.00   NaN  0.00  0.10  0.35  0.69  0.97  1.45  1.83   2.13
# 2016 2016-09-20  0.17   NaN  0.30  0.49  0.61  0.79  0.93  1.20  1.50   1.69
# 2017 2017-09-18  0.96   NaN  1.05  1.18  1.30  1.40  1.54  1.83  2.06   2.23
# 2018 2018-09-20  2.03   NaN  2.17  2.37  2.58  2.81  2.89  2.96  3.03   3.07
# 2019 2019-09-18  1.94  1.93  1.95  1.91  1.87  1.77  1.72  1.68  1.76   1.80
# 2020 2020-09-18  0.09  0.10  0.10  0.12  0.13  0.14  0.16  0.29  0.48   0.70
# 2021 2021-09-20  0.06  0.05  0.04  0.05  0.07  0.23  0.45  0.83  1.12   1.31
# 2022 2022-09-19  2.62  3.02  3.37  3.87  4.05  3.95  3.90  3.69  3.62   3.49
#
#       20 Yr  30 Yr
# Year
# 1990    NaN   9.06
# 1991    NaN   7.92
# 1992    NaN   7.32
# 1993    NaN   6.04
# 1994   7.90   7.75
# 1995   6.64   6.53
# 1996   7.15   7.00
# 1997   6.44   6.38
# 1998   5.37   5.18
# 1999   6.47   6.05
# 2000   6.23   5.97
# 2001   5.59   5.56
# 2002   4.80    NaN
# 2003   5.12    NaN
# 2004   4.91    NaN
# 2005   4.60    NaN
# 2006   4.94   4.86
# 2007   4.99   4.96
# 2008   4.12   4.08
# 2009   4.14   4.19
# 2010   3.57   3.87
# 2011   2.82   3.20
# 2012   2.58   2.97
# 2013   3.52   3.80
# 2014   3.12   3.37
# 2015   2.58   2.93
# 2016   2.09   2.43
# 2017   2.56   2.80
# 2018   3.15   3.21
# 2019   2.06   2.25
# 2020   1.24   1.45
# 2021   1.79   1.85
# 2022   3.77   3.52
